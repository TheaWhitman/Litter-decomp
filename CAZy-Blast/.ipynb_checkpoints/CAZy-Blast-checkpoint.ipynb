# %%
import rpy2
import screed
import pandas as pd
from collections import Counter
import numpy as np
import os
# Importing python packages - not necessarily used

# %%
# %load_ext rmagic
# Loading the rmagic extension, so we can run R code in the notebook, by typing %%R at the top of the cell
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %%
# %%R
# #source("http://bioconductor.org/biocLite.R")
# #biocLite("phyloseq")
# # Installing phyloseq package for making heatmaps
# # It asks for input - we want "a" for update all. ("s"ome, "n"one)
# # Don't need to do this every time
# Out:
# NULL

# %%
# %%R
# library(seqinr)
# library(ggplot2)
# library(plyr)
# library("phyloseq")
# # Load required packages

# %%
ls
# Out:
# CAZy-Blast.ipynb                        uparse_blast_output_cazy_counts_11.txt
# SampleData.txt                          uparse_blast_output_cazy_counts_56.txt

# %%
# %%R
# files = list.files(path = ".", pattern=c("uparse_blast_output_cazy_counts","*.txt"))
# # Creates a list of all the uparse filenames that end with .txt in the current directory
# Samples <- files
# Samples <- gsub("(.+)_(.+)(.txt)","\\2",files)
# Samples
# # Gets the ID number (anything that comes between the last underscore and .txt (whatever is in the second set of parentheses))
# Out:
# [1] "11" "56"

# %%
# %%R
# # Want to make a new table that has the CAZy ID, then the count for each sample, named as its sample ID
# # Could modify to look up treatment, etc. based on sample ID, or group by them, etc. For now just ID.
# CAZyTable.f <- function(x){
#     CAZy <- data.frame()
#     for (i in x) {
#         Sample <- as.character(gsub("(.+)_(.+)(.txt)","\\2",i))
#         CAZyt <- read.table(i, sep="\t", col.names=c("ID", Sample))
#         CAZy<-join(CAZy, CAZyt, type="full")
#     }
#     CAZy[is.na(CAZy)] <- 0
#     # Replaces NAs with 0's
#     CAZyComb<<-CAZy
# }
# # It adds an X in front of the ID for now - can be fixed later

# %%
# %%R
# CAZyTable.f(files)
# CAZyComb.m <- data.matrix(CAZyComb[,2:dim(CAZyComb)[2]])
# rownames(CAZyComb.m) <- paste0("OTU", 1:nrow(CAZyComb.m))
# CAZyComb.m[1:6,1:2]
# # This works on my test files where I rearranged the order, cut a value out, and made a giant value.
# # Turns the data frame into a matrix so it can become a physeq file
# # This is our fake OTU matrix
# Out:
# Joining by:
# Joining by: ID
#         X11     X56
# OTU1   2500 2500000
# OTU2    628     628
# OTU3  69358   69358
# OTU4  35374   35374
# OTU5 189743  189743
# OTU6   1341    1341

# %%
# %%R
# taxmat = as.matrix(CAZyComb[,1])
# rownames(taxmat) <- rownames(CAZyComb.m)
# colnames(taxmat) <- c("ID")
# taxmat
# # Making a fake taxonomy matrix where the ID of the "OTUs" (i.e., CAZymes) are matched up with their real IDs
# Out:
#        ID
# OTU1   "CBM21"
# OTU2   "CBM20"
# OTU3   "GH38"
# OTU4   "GH39"
# OTU5   "GH31"
# OTU6   "GT90"
# OTU7   "GH33"
# OTU8   "GH35"
# OTU9   "GH36"
# OTU10  "GH37"
# OTU11  "CBM56"
# OTU12  "CBM57"
# OTU13  "GT10"
# OTU14  "GT11"
# OTU15  "CBM52"
# OTU16  "GT17"
# OTU17  "CBM50"
# OTU18  "CBM51"
# OTU19  "GT19"
# OTU20  "GT40"
# OTU21  "GH103"
# OTU22  "GH102"
# OTU23  "GH101"
# OTU24  "GH100"
# OTU25  "GH107"
# OTU26  "GH106"
# OTU27  "GH105"
# OTU28  "GH104"
# OTU29  "cohesin"
# OTU30  "GH109"
# OTU31  "GH108"
# OTU32  "GT85"
# OTU33  "GT84"
# OTU34  "GT87"
# OTU35  "GT81"
# OTU36  "GT83"
# OTU37  "CBM62"
# OTU38  "GT89"
# OTU39  "CBM61"
# OTU40  "GH29"
# OTU41  "GH28"
# OTU42  "GT44"
# OTU43  "GH23"
# OTU44  "GH22"
# OTU45  "GH20"
# OTU46  "GH27"
# OTU47  "GH26"
# OTU48  "GH25"
# OTU49  "GH24"
# OTU50  "GH4"
# OTU51  "GH5"
# OTU52  "GH6"
# OTU53  "GH7"
# OTU54  "GH1"
# OTU55  "GH2"
# OTU56  "GH3"
# OTU57  "GH8"
# OTU58  "GH9"
# OTU59  "GH77"
# OTU60  "GH119"
# OTU61  "GH114"
# OTU62  "PL12"
# OTU63  "PL11"
# OTU64  "PL10"
# OTU65  "PL17"
# OTU66  "GH111"
# OTU67  "PL15"
# OTU68  "GH113"
# OTU69  "GH16"
# OTU70  "GH17"
# OTU71  "GH14"
# OTU72  "GH15"
# OTU73  "GH12"
# OTU74  "GH13"
# OTU75  "GH10"
# OTU76  "GH11"
# OTU77  "GT45"
# OTU78  "GH73"
# OTU79  "GH49"
# OTU80  "GT24"
# OTU81  "GH18"
# OTU82  "GH19"
# OTU83  "GT92"
# OTU84  "GT57"
# OTU85  "GH32"
# OTU86  "PL22"
# OTU87  "PL20"
# OTU88  "PL21"
# OTU89  "GT70"
# OTU90  "GT71"
# OTU91  "GT74"
# OTU92  "GT75"
# OTU93  "GT76"
# OTU94  "GT77"
# OTU95  "GH68"
# OTU96  "CBM60"
# OTU97  "GT54"
# OTU98  "GT12"
# OTU99  "GT47"
# OTU100 "GT13"
# OTU101 "CE7"
# OTU102 "CE6"
# OTU103 "CE5"
# OTU104 "CE4"
# OTU105 "CE3"
# OTU106 "CE2"
# OTU107 "CE1"
# OTU108 "GH115"
# OTU109 "GT16"
# OTU110 "CBM24"
# OTU111 "GH116"
# OTU112 "CE9"
# OTU113 "CE8"
# OTU114 "GT69"
# OTU115 "GH117"
# OTU116 "CBM37"
# OTU117 "GT14"
# OTU118 "GT15"
# OTU119 "GT61"
# OTU120 "GT60"
# OTU121 "GT67"
# OTU122 "GT66"
# OTU123 "PL16"
# OTU124 "GH67"
# OTU125 "GH98"
# OTU126 "GH99"
# OTU127 "CBM23"
# OTU128 "GH97"
# OTU129 "GH94"
# OTU130 "GH95"
# OTU131 "GH92"
# OTU132 "GH93"
# OTU133 "PL7"
# OTU134 "PL6"
# OTU135 "PL5"
# OTU136 "PL4"
# OTU137 "PL3"
# OTU138 "PL2"
# OTU139 "PL1"
# OTU140 "PL9"
# OTU141 "PL8"
# OTU142 "GH74"
# OTU143 "GH75"
# OTU144 "GH76"
# OTU145 "GT55"
# OTU146 "GT53"
# OTU147 "GH71"
# OTU148 "GH72"
# OTU149 "GT51"
# OTU150 "GH78"
# OTU151 "GH79"
# OTU152 "GT58"
# OTU153 "GT59"
# OTU154 "CBM18"
# OTU155 "GT23"
# OTU156 "GH88"
# OTU157 "CBM12"
# OTU158 "CBM13"
# OTU159 "CBM11"
# OTU160 "CBM16"
# OTU161 "GH89"
# OTU162 "GT1"
# OTU163 "GT2"
# OTU164 "GT3"
# OTU165 "GT4"
# OTU166 "GT5"
# OTU167 "GT7"
# OTU168 "GH81"
# OTU169 "GT9"
# OTU170 "GH82"
# OTU171 "GH85"
# OTU172 "GH84"
# OTU173 "GH87"
# OTU174 "GT50"
# OTU175 "CBM44"
# OTU176 "GT25"
# OTU177 "GT41"
# OTU178 "GT8"
# OTU179 "GH65"
# OTU180 "GH64"
# OTU181 "GH63"
# OTU182 "GH62"
# OTU183 "GH61"
# OTU184 "GT46"
# OTU185 "GT49"
# OTU186 "GT48"
# OTU187 "GT22"
# OTU188 "CBM30"
# OTU189 "CBM43"
# OTU190 "CBM42"
# OTU191 "GH50"
# OTU192 "GH110"
# OTU193 "CBM33"
# OTU194 "GT62"
# OTU195 "CBM35"
# OTU196 "CE13"
# OTU197 "CE12"
# OTU198 "CE11"
# OTU199 "CE10"
# OTU200 "GT64"
# OTU201 "CE16"
# OTU202 "CE15"
# OTU203 "CE14"
# OTU204 "GH52"
# OTU205 "GH53"
# OTU206 "CBM32"
# OTU207 "GH51"
# OTU208 "CBM34"
# OTU209 "GH57"
# OTU210 "GH54"
# OTU211 "GH55"
# OTU212 "CBM38"
# OTU213 "GH59"
# OTU214 "GT34"
# OTU215 "GT35"
# OTU216 "GT30"
# OTU217 "GT31"
# OTU218 "GT32"
# OTU219 "GT33"
# OTU220 "GT39"
# OTU221 "GH125"
# OTU222 "CBM3"
# OTU223 "GH121"
# OTU224 "GH120"
# OTU225 "GH123"
# OTU226 "PL14"
# OTU227 "SLH"
# OTU228 "GH48"
# OTU229 "GH70"
# OTU230 "GH45"
# OTU231 "GH44"
# OTU232 "GH47"
# OTU233 "GH46"
# OTU234 "GH43"
# OTU235 "GH42"
# OTU236 "GT27"
# OTU237 "GT26"
# OTU238 "CBM47"
# OTU239 "CBM46"
# OTU240 "CBM41"
# OTU241 "CBM40"
# OTU242 "GT21"
# OTU243 "GT20"
# OTU244 "GH66"
# OTU245 "CBM48"
# OTU246 "GT28"
# OTU247 "CBM1"
# OTU248 "CBM2"
# OTU249 "GT42"
# OTU250 "CBM4"
# OTU251 "CBM5"
# OTU252 "CBM6"
# OTU253 "CBM8"
# OTU254 "CBM9"
# OTU255 "CBM22"
# OTU256 "GH30"

# %%
# %%R
# sampledata <- sample_data(data.frame(read.csv("SampleData.txt")))
# sampledata
# # Importing fake sample data table
# Out:
# Sample Data:        [2 samples by 2 sample variables]:
#     Day Litter
# X11   2      X
# X56   1      X

# %%
# %%R
# library("ape")
# random_tree = rtree(ntaxa(physeq), rooted = TRUE, tip.label = taxa_names(physeq))

# %%
# %%R
# CAZy = otu_table(CAZyComb.m, taxa_are_rows = TRUE)
# IDs = tax_table(taxmat)
# physeq <- phyloseq(CAZy, IDs, sampledata, random_tree)
# # Making our whole fake phyloseq object

# %%
# %%R
# plot_bar(physeq, fill = "ID")
# # Just to see
# # Again, should be normalized

# %%
# %%R
# plot_heatmap(physeq, taxa.label = "ID", sample.order = sample_names(physeq), taxa.order = "ID")
# # YAY ok here is our fake heatmap where I deleted one of the enzymes and increased the other.
# # Otherwise, they were the same data.
# # This pipeline should work, though, on the full data.
# # However, we'll need to normalize them - this does not normalize by column or anything.

# %%
# %%R
# plot_tree(physeq, color = "Day", label.tips = "taxa_names", ladderize = "left",
#     plot.margin = 0.3)
# # Forget about this. Just fooling around.
